# %% [markdown]
# # Extracting ASINs
#
# Books are often linked to via Amazon and each product on Amazon has a 10 character ASIN ([Amazon Standard Identification Number](https://en.wikipedia.org/wiki/Amazon_Standard_Identification_Number)).
# In particular for books this is the same as the book's ISBN-10 which makes it easy to link.
#
# We're going to extract ASIN's from links to Amazon for the Hacker News dataset.

# %%
import numpy as np
import pandas as pd

import html

from pathlib import Path

# %%
hn_path = Path('../data/01_raw/hackernews2021.parquet')

df = pd.read_parquet(hn_path, use_nullable_dtypes=True).set_index('id')

# %%
pd.options.display.max_colwidth = 200

# %% [markdown]
# Our regular expression looks for something that looks like a URL starting with `amazon.` and containing `/dp/` and a 10 characters that are uppercase latin letters or digits.
#
# Because we're searching in the HTML escaped version we need to replace `/` with `&#x2F;` (which even occurs in the `href` for some reason).

# %%
import re
asin_re = re.compile(r'amazon\.[^"> ]*/dp/([A-Z0-9]{10})\W'.replace('/', '&#x2F;'))



example = '<a href="https:&#x2F;&#x2F;www.amazon.com&#x2F;x&#x2F;dp&#x2F;0884272079" rel="nofollow">'
asin_re.findall(example)
# Out:
# ['0884272079']

# %%
# %%time

asins = (
    df
    .text
    .dropna()
    .str.extractall(asin_re)
    [0]
    .rename('asin')
    .reset_index()
    .drop_duplicates(subset=['id', 'asin'])
    .set_index(['id', 'match'])
)
# Out:
# CPU times: user 7.3 s, sys: 51.8 ms, total: 7.35 s
# Wall time: 7.34 s

# %% [markdown]
# We get a long list of things that look like ASINs.

# %%
asins
# Out:
#                       asin
# id       match
# 25763413 0      0809301377
# 29430630 0      B00TQ5SEAI
# 27595409 0      0884272079
#          2      0884271536
# 26919349 0      B08F3CJ5HF
# ...                    ...
# 27651602 0      B005PLQIQ4
# 26745394 0      0062435612
#          1      B07PPW5V9C
#          2      B08FRRF68Q
# 26630286 0      B00JDMPOK2
#
# [2740 rows x 1 columns]

# %%
asin_count = asins.value_counts()

asin_count
# Out:
# asin
# 1594035229    7
# 0262632691    6
# B07N4DHFZM    5
# 0393009262    5
# 0465060730    5
#              ..
# 1413326390    1
# 1408703971    1
# 1408190303    1
# 1402791038    1
# B09H478XG4    1
# Length: 2454, dtype: int64

# %% [markdown]
# There are <200 ASINs that have come up more than once.

# %%
asin_count.value_counts()
# Out:
# 1    2243
# 2     158
# 3      40
# 4       7
# 5       4
# 7       1
# 6       1
# dtype: int64

# %% [markdown]
# ## Examining ASINs

# %% [markdown]
# The top 10 are all books (though there are some products further down the list)

# %%
def link_asin(asin):
    return f'<a href="https://www.amazon.com.au/dp/{asin}">{asin}</a>'

asin_count.reset_index().head(10).style.format({'asin': link_asin})
# Out:
# <style type="text/css">
# </style>
# <table id="T_c9a08">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9a08_level0_col0" class="col_heading level0 col0" >asin</th>
#       <th id="T_c9a08_level0_col1" class="col_heading level0 col1" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9a08_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c9a08_row0_col0" class="data row0 col0" ><a href="https://www.amazon.com.au/dp/1594035229">1594035229</a></td>
#       <td id="T_c9a08_row0_col1" class="data row0 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_c9a08_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c9a08_row1_col0" class="data row1 col0" ><a href="https://www.amazon.com.au/dp/0262632691">0262632691</a></td>
#       <td id="T_c9a08_row1_col1" class="data row1 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c9a08_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c9a08_row2_col0" class="data row2 col0" ><a href="https://www.amazon.com.au/dp/B07N4DHFZM">B07N4DHFZM</a></td>
#       <td id="T_c9a08_row2_col1" class="data row2 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c9a08_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c9a08_row3_col0" class="data row3 col0" ><a href="https://www.amazon.com.au/dp/0393009262">0393009262</a></td>
#       <td id="T_c9a08_row3_col1" class="data row3 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c9a08_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c9a08_row4_col0" class="data row4 col0" ><a href="https://www.amazon.com.au/dp/0465060730">0465060730</a></td>
#       <td id="T_c9a08_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c9a08_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c9a08_row5_col0" class="data row5 col0" ><a href="https://www.amazon.com.au/dp/0735224897">0735224897</a></td>
#       <td id="T_c9a08_row5_col1" class="data row5 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c9a08_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c9a08_row6_col0" class="data row6 col0" ><a href="https://www.amazon.com.au/dp/0143125788">0143125788</a></td>
#       <td id="T_c9a08_row6_col1" class="data row6 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c9a08_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c9a08_row7_col0" class="data row7 col0" ><a href="https://www.amazon.com.au/dp/0201178885">0201178885</a></td>
#       <td id="T_c9a08_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c9a08_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c9a08_row8_col0" class="data row8 col0" ><a href="https://www.amazon.com.au/dp/0578675862">0578675862</a></td>
#       <td id="T_c9a08_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c9a08_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c9a08_row9_col0" class="data row9 col0" ><a href="https://www.amazon.com.au/dp/1492180742">1492180742</a></td>
#       <td id="T_c9a08_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_asin = df.loc[asins.reset_index().id.drop_duplicates()]

df_asin
# Out:
#          title   url  \
# id
# 25763413  <NA>  <NA>
# 29430630  <NA>  <NA>
# 27595409  <NA>  <NA>
# 26919349  <NA>  <NA>
# 29586021  <NA>  <NA>
# ...        ...   ...
# 25709802  <NA>  <NA>
# 26283630  <NA>  <NA>
# 27651602  <NA>  <NA>
# 26745394  <NA>  <NA>
# 26630286  <NA>  <NA>
#
#                                                                                                                                                                                                              text  \
# id
# 25763413  Just a historical note, from 1964, a book by Buckminster Fuller: <i>Education Automation: Freeing the scholar to return to his studies</i><p>Even back then we had the technology and opportunity to...
# 29430630  <a href="https:&#x2F;&#x2F;www.youtube.com&#x2F;watch?v=J0dDTbA1fq8" rel="nofollow">https:&#x2F;&#x2F;www.youtube.com&#x2F;watch?v=J0dDTbA1fq8</a><p><a href="https:&#x2F;&#x2F;boardgamegeek.com&#x...
# 27595409  Eliyahu M. Goldratt has some great books explaining in great detail why this is the case:
# <a href="https:&#x2F;&#x2F;www.amazon.com&#x2F;x&#x2F;dp&#x2F;0884272079" rel="nofollow">https:&#x2F;&#x2F...
# 26919349  This has 8 mp
# <a href="https:&#x2F;&#x2F;www.amazon.com&#x2F;dp&#x2F;B08F3CJ5HF&#x2F;ref=emc_b_5_mob_t" rel="nofollow">https:&#x2F;&#x2F;www.amazon.com&#x2F;dp&#x2F;B08F3CJ5HF&#x2F;ref=emc_b_5_mob...
# 29586021  Read: the power of now<p><a href="https:&#x2F;&#x2F;www.amazon.com&#x2F;Power-Now-Guide-Spiritual-Enlightenment&#x2F;dp&#x2F;1577314808" rel="nofollow">https:&#x2F;&#x2F;www.amazon.com&#x2F;Power-...
# ...                                                                                                                                                                                                           ...
# 25709802  Then in that case they will surely be desirous of de-platforming the toxic content on Twitter, which advocates, among other things, the destruction of Israel By Iran and the internment of Uyghurs ...
# 26283630  Nice piece, was talking to a friend about this yesterday, particularly regarding online community. Our conjecture ended up being that communities don’t scale, which is why Twitter fails, and Faceb...
# 27651602  No, it is ~$3 for a standard ~5oz size.<p><a href="https:&#x2F;&#x2F;www.amazon.com&#x2F;Crest-Complete-Whitening-Toothpaste-Triple&#x2F;dp&#x2F;B005PLQIQ4" rel="nofollow">https:&#x2F;&#x2F;www.am...
# 26745394  So I can kind of see what you are trying to get at with your product. There are 3 books I recommend you read to help you further:<p>1. &quot;Competing Against Luck&quot; by Clay Christensen <a hre...
# 26630286  1. Read Code by Charles Petzold.<p><a href="https:&#x2F;&#x2F;www.amazon.com&#x2F;Code-Language-Computer-Developer-Practices-ebook&#x2F;dp&#x2F;B00JDMPOK2&#x2F;" rel="nofollow">https:&#x2F;&#x2F;w...
#
#           dead          by  score        time                 timestamp  \
# id
# 25763413  <NA>      yboris   <NA>  1610552713 2021-01-13 15:45:13+00:00
# 29430630  <NA>        iams   <NA>  1638543145 2021-12-03 14:52:25+00:00
# 27595409  <NA>      sly010   <NA>  1624387075 2021-06-22 18:37:55+00:00
# 26919349  <NA>   hnnnnnnng   <NA>  1619212979 2021-04-23 21:22:59+00:00
# 29586021  <NA>    quadcore   <NA>  1639700835 2021-12-17 00:27:15+00:00
# ...        ...         ...    ...         ...                       ...
# 25709802  <NA>    tatrajim   <NA>  1610251761 2021-01-10 04:09:21+00:00
# 26283630  <NA>        dmje   <NA>  1614416939 2021-02-27 09:08:59+00:00
# 27651602  <NA>  lotsofpulp   <NA>  1624802246 2021-06-27 13:57:26+00:00
# 26745394  <NA>     luthfur   <NA>  1617927582 2021-04-09 00:19:42+00:00
# 26630286  <NA>     runjake   <NA>  1617066726 2021-03-30 01:12:06+00:00
#
#              type    parent  descendants  ranking  deleted
# id
# 25763413  comment  25760960         <NA>     <NA>     <NA>
# 29430630  comment  29430521         <NA>     <NA>     <NA>
# 27595409  comment  27593834         <NA>     <NA>     <NA>
# 26919349  comment  26919315         <NA>     <NA>     <NA>
# 29586021  comment  29585542         <NA>     <NA>     <NA>
# ...           ...       ...          ...      ...      ...
# 25709802  comment  25709456         <NA>     <NA>     <NA>
# 26283630  comment  26274450         <NA>     <NA>     <NA>
# 27651602  comment  27651219         <NA>     <NA>     <NA>
# 26745394  comment  26734079         <NA>     <NA>     <NA>
# 26630286  comment  26629722         <NA>     <NA>     <NA>
#
# [2396 rows x 13 columns]

# %% [markdown]
# # Exporting
#
# Let's export some examples for further analysis.
#
# We'll get the parent data for context.

# %%
df_asin = (
    df_asin.filter(regex='.*(?!_parent)$')
    .merge(df[['text', 'title', 'type', 'url']],
           left_on='parent',
           right_index=True,
           how='left',
           suffixes=('', '_parent'))
)

# %% [markdown]
# And clean the text by unescaping the HTML and reversing the formatdoc.

# %%
df_asin['clean_text'] = (
    df_asin['text']
    .map(html.unescape)
    .str.replace('</?i>', '**', regex=True)
    .str.replace('<p>', '\n\n')
    .replace('<a href="(.*?)".*?>.*?</a>',r'\1', regex=True)
)

# %%
has_text = df_asin['text_parent'].notna()

df_asin.loc[has_text, 'clean_text_parent'] = (
    df_asin.loc[has_text, 'text_parent']
    .map(html.unescape)
    .str.replace('</?i>', '**', regex=True)
    .str.replace('<p>', '\n\n')
    .replace('<a href="(.*?)".*?>.*?</a>',r'\1', regex=True)
)

# %%
columns = ['id', 'clean_text', 'clean_text_parent', 'by', 'timestamp', 'type', 'type_parent', 'parent', 'text']

# %%
