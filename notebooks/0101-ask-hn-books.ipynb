# %% [markdown]
# # Ask HN Book Recommendations
#
# Let's find all comments from Ask HN threads looking for book recommendations

# %% [markdown]
# # Load the Data

# %%
from pathlib import Path
import pandas as pd
import xxhash

# %% [markdown]
# Read in all Hacker News Stories from 2021, which [can be downloaded from Kaggle](https://www.kaggle.com/datasets/edwardjross/hackernews-2021-comments-and-stories) (extracted from the BigQuery dataset).

# %%
df = pd.read_parquet('../data/01_raw/hackernews2021.parquet').set_index('id')

# %%
df
# Out:
#          title   url                                               text  dead  \
# id
# 27405131  None  None  They didn&#x27;t say they <i>weren&#x27;t</i> ...  None
# 27814313  None  None  Check out <a href="https:&#x2F;&#x2F;www.remno...  None
# 28626089  None  None  Like a million-dollars pixel but with letters....  None
# 27143346  None  None                                Not the question...  None
# 29053108  None  None  There’s the Unorganized Militia of the United ...  None
# ...        ...   ...                                                ...   ...
# 27367848  None  None  Housing supply isn’t something that can’t chan...  None
# 28052800  None  None  Final Fantasy XIV has been experiencing consta...  None
# 28052805  None  None                            How did you resolve it?  None
# 26704924  None  None  This hasn&#x27;t been my experience being vega...  None
# 27076885  None  None  Death services tread a very fine moral line.  ...  None
#
#                    by  score        time                 timestamp     type  \
# id
# 27405131  chrisseaton    NaN  1622901869 2021-06-05 14:04:29+00:00  comment
# 27814313      noyesno    NaN  1626119705 2021-07-12 19:55:05+00:00  comment
# 28626089  alainchabat    NaN  1632381114 2021-09-23 07:11:54+00:00  comment
# 27143346     SigmundA    NaN  1620920426 2021-05-13 15:40:26+00:00  comment
# 29053108       User23    NaN  1635636573 2021-10-30 23:29:33+00:00  comment
# ...               ...    ...         ...                       ...      ...
# 27367848         JCM9    NaN  1622636746 2021-06-02 12:25:46+00:00  comment
# 28052800      amyjess    NaN  1628017217 2021-08-03 19:00:17+00:00  comment
# 28052805    8ytecoder    NaN  1628017238 2021-08-03 19:00:38+00:00  comment
# 26704924     pacomerh    NaN  1617657938 2021-04-05 21:25:38+00:00  comment
# 27076885      curryst    NaN  1620400897 2021-05-07 15:21:37+00:00  comment
#
#               parent  descendants  ranking deleted
# id
# 27405131  27405089.0          NaN      NaN    None
# 27814313  27812726.0          NaN      NaN    None
# 28626089  28626017.0          NaN      NaN    None
# 27143346  27143231.0          NaN      NaN    None
# 29053108  29052087.0          NaN      NaN    None
# ...              ...          ...      ...     ...
# 27367848  27367172.0          NaN      NaN    None
# 28052800  28050798.0          NaN      NaN    None
# 28052805  28049375.0          NaN      NaN    None
# 26704924  26704794.0          NaN      NaN    None
# 27076885  27075961.0          NaN      NaN    None
#
# [4155063 rows x 13 columns]

# %% [markdown]
# # Split the Data
#
# The data will be split deterministically by the by the root story.
# This allows using features about the comment thread.
#
# ## Finding the root
#
# For each comment the root can be found by walking up the parents recursively.

# %%
parent_dict = df['parent'].fillna(df.index.to_series()).to_dict()

root_dict = {}

for item, parent in parent_dict.items():
    while parent in parent_dict:
        grandparent = parent_dict[parent]
        if parent == grandparent:
            break
        parent = grandparent
    root_dict[item] = parent
    
df['root'] = df.index.map(root_dict)

# %% [markdown]
# ## Deterministic Splitting
#
# The hash of the root id with a fixed salt gives a deterministic random split.
# Choose a 50% training set.

# %%
def bucket(s, salt='hnbooks'):
    return xxhash.xxh32_intdigest(str(s)+salt) % 100

bucket = df['root'].apply(bucket)

df['bucket'] = bucket

df['train'] = bucket < 50

# %% [markdown]
# # Finding HN Book Recommendations
#
# We'll use a simple heuristic; any threads containing the work "book" or "textbook" and a work like "recommend", "best", "favorite", or "top" will be included.

# %%
sample = df.query('train').copy()

# %%
ask_hn_books = sample[
    sample['title']
    .str.contains(r'\b(?:text)?books?\b', regex=True) &
    sample['title']
    .str.contains(r'\b(?:recommend(?:ed)|best|favou?rite|top)\b', case=False, regex=True)
]

# %%
len(ask_hn_books)
# Out:
# 44

# %%
pd.options.display.max_colwidth = 1000
pd.options.display.max_columns = 100

# %% [markdown]
# The majority of these are threads for book recommendations.

# %%
ask_hn_books[['title']].T
# Out:
# id                                                                         28129039  \
# title  Why is it a “red flag” if someone’s favorite book is The Catcher in the Rye?
#
# id                                           29668228  \
# title  Ask HN: What's the best book you read in 2021?
#
# id                                             28391738  \
# title  Ask HN: Best books on modern distributed systems
#
# id                                         27847072  \
# title  The all-time best software engineering books
#
# id                                                 28308141  \
# title  Ask HN: What are your top 5 favorite computer books?
#
# id                                        28456318  \
# title  Ask HN: What's the best book on AWS Lambda?
#
# id                                            28181074  \
# title  Ask HN: Best (practical) books on web security?
#
# id                                                           29686739  \
# title  Ask HN: What is your favorite book that you've read this year?
#
# id                                                     29317984  \
# title  Best non-fiction books of 2021, according to Tyler Cowen
#
# id                                                  29364196  \
# title  Ask HN: What's your favorite book about chaos theory?
#
# id                                                           29146838  \
# title  Ask HN: Best book to learn C++ as a professional C programmer?
#
# id                                                                            29450246  \
# title  Show HN: Yearly Faves – track and share your favorite books and music from 2021
#
# id                                                       25999330  \
# title  Ask HN: What are your favorite non-fiction books, and why?
#
# id                                           29493803  \
# title  Non-business books for 2021 recommended by VCs
#
# id                                                                          25824260  \
# title  Ask HN: Best applied statistics books aimed at machine learning practitioners
#
# id                                                                   26543525  \
# title  Show HN: Reclist.me – Share your favorite books, podcasts, newsletters
#
# id                                                                    28830391  \
# title  Ask HN: Best books/blogs/courses to learn advanced networking concepts?
#
# id                                                29042241  \
# title  Show HN: Top programming books for early developers
#
# id                                        26044792  \
# title  Show HN: Best books and courses for AWS MSK
#
# id                                                                             27324739  \
# title  Show HN: I Built an app to show you the most recommended books on business, tech
#
# id                                       29538595  \
# title  Ask HN: What are your favourite textbooks?
#
# id                                                                         26213907  \
# title  Bookfeed.io – An RSS feed of newly released books from your favorite authors
#
# id                                                                          27802522  \
# title  Ask HN: What's the best CS or software engineering book you've read recently?
#
# id                                                                    27961170  \
# title  What are your favorite MLOps courses, tools, books and research papers?
#
# id                                                                             27807639  \
# title  Ask HN: What are some favorite books that provide insight into other industries?
#
# id                                                                 28588411  \
# title  Ask HN: What are some of your favorite textbooks or technical books?
#
# id                                                                        28523387  \
# title  Show HN: RemoteDream – Find and book the best ho(s)tels to work remote from
#
# id                                                                          25857629  \
# title  Amazon story: Late 90s, the internet was growing 2300%, book was best to sell
#
# id                                               26624661  \
# title  Ask HN: Best book/resources on business modelling?
#
# id                                                                 29712869  \
# title  Top programming, mathematics, physics, and science books: part eight
#
# id                                                                     29573390  \
# title  Ask HN: Best place to purchase (used) technical books that's not Amazon?
#
# id                                                                  27673186  \
# title  What is the absolute best book for re-learning forgotten math for CS?
#
# id                                                                    28267422  \
# title  Ask HN: What are the best books on relational database modeling in SQL?
#
# id                                   25675207  \
# title  Ten best non-war history books of 2020
#
# id                                                       27846316  \
# title  Ask HN: What is your favorite introductory-level textbook?
#
# id                                                      27646981  \
# title  Experts recommending the five best books in their subject
#
# id                                           26406961  \
# title  The only 10 books AOC ever recommended to read
#
# id                                            29706029  \
# title  Best AI and Deep learning books to read in 2022
#
# id                                                                           26157608  \
# title  Bookfeed.io: RSS feed listing all new book releases from your favorite authors
#
# id                                                                   29247624  \
# title  Amazon Books editors announce best 2021 general interest science books
#
# id                                                                      29182386  \
# title  Ask HN: What are some of the best well-written books on computer science?
#
# id                                                        29726026  \
# title  Ask HN: What is your favorite book for learning statistics?
#
# id                                                                             25922349  \
# title  Ask HN: Best tech focused (technical or non-technical) books you’ve read lately?
#
# id                                                27641976
# title  Ask HN: What is the best business book you've read?

# %%
sample['ask_hn_books'] = False
sample.loc[sample['root'].isin(ask_hn_books.index), 'ask_hn_books'] = True

# %%
pd.options.display.max_colwidth = 500

# %%
sample.query('ask_hn_books')[['text']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          text
# id
# 29676102  I also read it this year.<p>It came very close to me. The society of the book was very similar to the society in which I grew up, Soviet Union in 90s.<p>Some of the lines from the book:<p>&quot;.. the social consience completely dominates the individual conscience, instead of striking a balance with it. We don&#x27;t cooperate - we obey. We fear being outcast, being called lazy, dysfunctional, egoizing. We fear our neighbor&#x27;s opinion more than we respect our own freedom of choice.&quot;...
# 29673970  I re-read the series this year too. The books are just as good the second time &#x27;round--maybe better. There&#x27;s a fifth one new since my last read-through, and another in the offing perhaps[1].<p>Saunders&#x27; writing is for people who think that Gibson spends too much time explaining things.[2]<p>You do have to read between the lines a lot, and also stop a lot to figure out how bits of the world work, but the world-building is among the best I&#x27;ve seen. A fully worked out, human...
# 29669184                                                                                                                                                                                                                                                                                                                                                              - Existential Rationalism: Handling Hume&#x27;s Fork (second edition)\n- Living with the Himalayan Masters\n- The Outsider\n- Hirohito: Behind the Myth
# 29669495                                                                                                                                                                                                                                                                                                                                                                                                                                                                           The Coming of Neo-Feudalism by Joel Kotkin
# 29669067                                                                                                                                                                                                                                                                                                                                                          Probably <i>Reaper</i>, by Will Wight. It’s not an insightful nonfiction book or a piece of high literature, but the whole Cradle series is very, very fun.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 29669044                                                                                                                                                                                                                                                                                                                                                                                                      If you like that, you might like r&#x2F;progressionfantasy. They really drill down on the hero’s journey genre.
# 29669957                                                                                                                                                                                                                                                                                                                                                                                                                                Skip the retelling and go straight to the source, <i>South</i>, by Ernest Shackleton.
# 28404781                                                                                                                                                                                                                                                                         @skrtskrt: Sorry for hijacking this post, but is there a way to contact you directly (my email is in my profile)? Your approach to building Django apps closely resonates with me and I would love to discuss these concepts in more detail.
# 26556264                                                                                                                                                                                                                                                                                                                                                  Thanks for your comment! I really appreciate!<p>I&#x27;m using the Read Only permissions (the most basic). There is no lower permissions level than that.<p>thanks!
# 29672750                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Make sure to read the sequal: Children of Ruin.
#
# [899 rows x 1 columns]

# %%
sample[['ask_hn_books']].to_parquet('../data/02_intermediate/ask_hn_books.parquet')
