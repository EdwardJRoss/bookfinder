# %% [markdown]
# # Ask HN Books
#
# Hacker News has a type of post called "Ask HN" where people ask questions. Book recommendations is one kind of frequently asked question.

# %%
import numpy as np
import pandas as pd

import html

from pathlib import Path

# %%
hn_path = Path('../data/01_raw/hackernews2021.parquet')

df = pd.read_parquet(hn_path, use_nullable_dtypes=True).set_index('id')

# %%
pd.options.display.max_colwidth = 400

# %% [markdown]
# Let's find all the parents

# %%
from tqdm.notebook import tqdm

from collections import defaultdict

parent_dict = df['parent'].dropna().to_dict()

parent_dict = defaultdict(lambda: pd.NA, parent_dict)


MAX_DEPTH = 50

df['parent0'] = df['parent']

for idx in tqdm(range(MAX_DEPTH)):
    last_col = f'parent{idx}'
    col = f'parent{idx+1}'
    
    df[col] = df[last_col].map(parent_dict, na_action='ignore')
    if df[col].isna().all():
        del df[col]
        break


root = None

for col in df.filter(regex='parent\d+').iloc[:,::-1]:
    if root is None:
        root = df[col]
    else:
        root = root.combine_first(df[col])
df['root'] = root
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
df['depth'] = df.filter(regex='parent\d+').notna().sum(axis=1)

# %% [markdown]
# ## Ask HN Books
#
# Let's search for all Ask HN posts with books or textbooks in the title.

# %%
ask_hn_books = df[df['title'].str.contains(r'Ask HN.*\b(?:text)?books?\b', regex=True)]

ask_hn_books
# Out:
#                                                                                     title  \
# id
# 29622942     Ask HN: How much do you love discussing books with the people who read them?
# 26624324  Ask HN: Is it worth it for a tech startup founder to write a chapter in a book?
# 29304013                      Ask HN: Forgot this name of product design book, any ideas?
# 27394502                                          Ask HN: Have you stopped reading books?
# 25831897          Ask HN: What programming tutorials/courses/e-books do you wish existed?
# ...                                                                                   ...
# 27225583                             Ask HN: Take notes with Apple Pencil on a ePub book?
# 29688332                           Ask HN: What are the best tech books you read in 2021?
# 28208817                              Ask HN: Any good books about stress and management?
# 26888567                   Ask HN: Publishing a book about my time at a prominent startup
# 25904433                                     Ask HN: Which book do you want to read next?
#
#            url  \
# id
# 29622942  <NA>
# 26624324  <NA>
# 29304013  <NA>
# 27394502  <NA>
# 25831897  <NA>
# ...        ...
# 27225583  <NA>
# 29688332  <NA>
# 28208817  <NA>
# 26888567  <NA>
# 25904433  <NA>
#
#                                                                                                                                                                                                                                                                                                                                                                                                                      text  \
# id
# 29622942                                                                                                                                                                                                                                                          And how do you discuss them? what type of discussions you love about books?.
# What do you think about discussing books with a stranger on the internet?
# 26624324  I was approached with a proposal to write a chapter in an Elseveir book.  I am a startup founder so time is pretty scarce and this will take up all my free time for the next couple months. It sounds interesting to think about our field from a different, more scientific perspective, but 2 months of life might be a bit too high of a price if there are no other outputs.<p>Problem is that when I w...
# 29304013                                                                                                                                                      I forgot the title of the book and name of the author, but all I can recall is it&#x27;s written by a guy that worked at Uber.. Anyone got ideas? Thank you very much. If you have other recommendations too, I&#x27;d love to check them out, thank you :)
# 27394502  Reading has always been a big part of my life but I was out with friends the other day and they asked what I was reading and I said that I feel like I&#x27;m reading more than ever but that I haven&#x27;t bought or read a book for over a year. In their place is a mix of podcasts, blogs, other articles, YouTube videos, and HN (a lot of which aren&#x27;t reading at all but scratch the same itch ...
# 25831897                                                                                                                                                                                                             Even though we are spoiled for choice with the amount of programming learning materials produced each year, I imagine there are still some important topics which do not get as much love as others.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 27225583                            I read ePub books on Apple Books on my Mac or iPad. I hate that I have to take notes in a separate notebook while iPad’s pencil is so great, and taking notes as annotations on the book itself would be so much more intuitive and useful. Anybody here have any solutions for this? Any app that solves this problem creatively by automagically converting ePub to something else?
# 29688332                                                                                                                                                                                                                                    Mine are Statistical Inference in Computer Age, and Transactional Information Systems. Curious what other books teach us powerful concepts and tools that carry us a long way
# 28208817                           I am constantly involved in multiple projects with different clients. I have read about that multitasking is stressful and that meditation is good against stress. But I wonder if there is a book on how to manage the situation without feeling stressed in the first place. I want a system that works rather than a cure for the symptoms or something like that. Any suggestions?
# 26888567  Looking for advice, throwaway account for obvious reasons.<p>Early employee at a startup for ~6 years from seed stage.
# Startup has successfully raised multiple rounds of funding.
# Profitable but pre-exit.<p>I&#x27;ve kept detailed notes and have numerous interesting -&gt; to me at least, stories to tell.
# Stories from founder histories. Growing Pains. Customer problems. Raising. Finding fit and ...
# 25904433                                                                                                                                                                                                                                                                                                                                                                And what&#x27;s your reading frequency for books?
#
#           dead              by  score        time                 timestamp  \
# id
# 29622942  <NA>         NithurM      1  1639993717 2021-12-20 09:48:37+00:00
# 26624324  True     isitworthit      1  1617035558 2021-03-29 16:32:38+00:00
# 29304013  <NA>         joshxyz      7  1637568639 2021-11-22 08:10:39+00:00
# 27394502  <NA>           anm89     31  1622820202 2021-06-04 15:23:22+00:00
# 25831897  <NA>       carlmungz      2  1611051711 2021-01-19 10:21:51+00:00
# ...        ...             ...    ...         ...                       ...
# 27225583  <NA>   reacharavindh      3  1621537276 2021-05-20 19:01:16+00:00
# 29688332  <NA>        hintymad     95  1640477353 2021-12-26 00:09:13+00:00
# 28208817  <NA>        waspight      2  1629200669 2021-08-17 11:44:29+00:00
# 26888567  True  startupinsider      1  1619007198 2021-04-21 12:13:18+00:00
# 25904433  <NA>        humility     34  1611589285 2021-01-25 15:41:25+00:00
#
#            type  parent  ...  parent36  parent37  parent38  parent39 parent40  \
# id                       ...
# 29622942  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 26624324  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 29304013  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 27394502  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 25831897  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# ...         ...     ...  ...       ...       ...       ...       ...      ...
# 27225583  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 29688332  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 28208817  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 26888567  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 25904433  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
#
#          parent41 parent42 parent43  root depth
# id
# 29622942     <NA>     <NA>     <NA>  <NA>     0
# 26624324     <NA>     <NA>     <NA>  <NA>     0
# 29304013     <NA>     <NA>     <NA>  <NA>     0
# 27394502     <NA>     <NA>     <NA>  <NA>     0
# 25831897     <NA>     <NA>     <NA>  <NA>     0
# ...           ...      ...      ...   ...   ...
# 27225583     <NA>     <NA>     <NA>  <NA>     0
# 29688332     <NA>     <NA>     <NA>  <NA>     0
# 28208817     <NA>     <NA>     <NA>  <NA>     0
# 26888567     <NA>     <NA>     <NA>  <NA>     0
# 25904433     <NA>     <NA>     <NA>  <NA>     0
#
# [176 rows x 59 columns]

# %% [markdown]
# Some of these are also about things like reading books.
# There are only 176 threads so we could classify them manually.
#
# However we could go further and search for recommendations using words like "recommend", "best" or "top".

# %%
book_recommendations = ask_hn_books[ask_hn_books['title'].str.contains(r'\b(?:recommend(?:ed)|best|favou?rite|top)\b', case=False, regex=True)]

# %% [markdown]
# There are 42 threads and almost all of them are asking for book recommendations.

# %%
book_recommendations
# Out:
#                                                                                      title  \
# id
# 29710173                           Ask HN: What are your favourite computer science books?
# 28659626                            Ask HN: What is the best programming book you've read?
# 25987664                      Ask HN: Recommended books and papers on distributed systems?
# 29668228                                    Ask HN: What's the best book you read in 2021?
# 28391738                                  Ask HN: Best books on modern distributed systems
# 28308141                              Ask HN: What are your top 5 favorite computer books?
# 29602228                   Ask HN: What are the best books for professional effectiveness?
# 29634694                                  Ask HN: What was the best book you read in 2021?
# 28456318                                       Ask HN: What's the best book on AWS Lambda?
# 28181074                                   Ask HN: Best (practical) books on web security?
# 28162971                   Ask HN: What is your favorite “A Page a Day”/daily format book?
# 29686739                    Ask HN: What is your favorite book that you've read this year?
# 29364196                             Ask HN: What's your favorite book about chaos theory?
# 29146838                    Ask HN: Best book to learn C++ as a professional C programmer?
# 25999330                        Ask HN: What are your favorite non-fiction books, and why?
# 25824260     Ask HN: Best applied statistics books aimed at machine learning practitioners
# 28830391           Ask HN: Best books/blogs/courses to learn advanced networking concepts?
# 26909996                   Ask HN: Best UI/UX book relevant to 2021 and the rise of Figma?
# 29538595                                        Ask HN: What are your favourite textbooks?
# 27802522     Ask HN: What's the best CS or software engineering book you've read recently?
# 28659636                            Ask HN: What is the best programming book you've read?
# 27807639  Ask HN: What are some favorite books that provide insight into other industries?
# 28124164                      Ask HN: What is the best technical book you've read in 2021?
# 28588411              Ask HN: What are some of your favorite textbooks or technical books?
# 26624661                                Ask HN: Best book/resources on business modelling?
# 26087495    Ask HN: Best [audio] books on how to create a startup during social distancing
# 29573390          Ask HN: Best place to purchase (used) technical books that's not Amazon?
# 26317481                                    Ask HN: What are your favorite business books?
# 28267422           Ask HN: What are the best books on relational database modeling in SQL?
# 27846316                        Ask HN: What is your favorite introductory-level textbook?
# 25846115              Ask HN: Best books on “friendship” and how to make/maintain friends?
# 26774350                                     Ask HN: What are your favorite toddler books?
# 27839815                                   Ask HN: What's your favorite coffee table book?
# 26833319           Ask HN: Best book for software engineers (besides the well-known ones)?
# 29457470                      Ask HN: What is the best book on data visualization in 2021?
# 29182386         Ask HN: What are some of the best well-written books on computer science?
# 29726026                       Ask HN: What is your favorite book for learning statistics?
# 25922349  Ask HN: Best tech focused (technical or non-technical) books you’ve read lately?
# 26511180                                              Ask HN: What is the best book on AI?
# 27641976                               Ask HN: What is the best business book you've read?
# 29661400                      Ask HN: "Know Your Hardware”: best books/resources to learn?
# 29688332                            Ask HN: What are the best tech books you read in 2021?
#
#            url  \
# id
# 29710173  <NA>
# 28659626  <NA>
# 25987664  <NA>
# 29668228  <NA>
# 28391738  <NA>
# 28308141  <NA>
# 29602228  <NA>
# 29634694  <NA>
# 28456318  <NA>
# 28181074  <NA>
# 28162971  <NA>
# 29686739  <NA>
# 29364196  <NA>
# 29146838  <NA>
# 25999330  <NA>
# 25824260  <NA>
# 28830391  <NA>
# 26909996  <NA>
# 29538595  <NA>
# 27802522  <NA>
# 28659636  <NA>
# 27807639  <NA>
# 28124164  <NA>
# 28588411  <NA>
# 26624661  <NA>
# 26087495  <NA>
# 29573390  <NA>
# 26317481  <NA>
# 28267422  <NA>
# 27846316  <NA>
# 25846115  <NA>
# 26774350  <NA>
# 27839815  <NA>
# 26833319  <NA>
# 29457470  <NA>
# 29182386  <NA>
# 29726026  <NA>
# 25922349  <NA>
# 26511180  <NA>
# 27641976  <NA>
# 29661400  <NA>
# 29688332  <NA>
#
#                                                                                                                                                                                                                                                                                                                                                                                                                      text  \
# id
# 29710173                                                                                                                                                                                                                                                                                                                                                                                                             <NA>
# 28659626                                                                                                                                                                                                                                                                                                                                                                                                             <NA>
# 25987664  The most recent and complete book on Distributed Systems that I&#x27;m aware of is Design Data Intensive Application (2017). I&#x27;m currently reading it. I also want to learn about other problems and ideas:<p>- Ideas that stood the test of times<p>- Ideas that were not feasible but now possible thanks to hardware improvement.<p>So, what&#x27;s your recommendations for books and papers on the...
# 29668228                                                                                                                                                                                                                                                                                                             Yearly thread. It can be books published on 2021 or in previous years (but that you read this year.)
# 28391738  I&#x27;ve read designing data intensive systems and it covered distributed systems a bit.<p>I don&#x27;t find most textbooks to be an actually good intro outside of a course setting. For example, I own Andrew Tannenbaum&#x27;s Distributed System book and a few others of his. But his writing style is too dense for me to make enough progress without giving up.<p>What other books (probably not te...
# 28308141                                                                                                                                                                                                                                                                                     I&#x27;m looking to expand my book collection and I&#x27;d like to know what this community is reading related to computers.
# 29602228                                                                                                                                                                                                                                                                                                                   What books have helped you be more effective at work that apply to most “knowledge work” jobs?
# 29634694                                                                                                                                                                                                                                                                                                                                                                                                             <NA>
# 28456318                                                                                                                                                                                                                                                                                                                                                                                                             <NA>
# 28181074  I would like to learn more about topics like:<p>- DMZ<p>- bastion hosts (should we use them? Why or why not)<p>- ssh<p>- best practices<p>in the context of web development on the cloud. I&#x27;ve found a lot of material but they are very cloud-focused (aws&#x2F;gcp security, for example) or rely a lot on Kubernetes (which I&#x27;m not using). I&#x27;m a solo-developer maintaining a simple Saas...
# 28162971                                                                                                                                                                                                                       For example:<p>A Poem for Every Night of the Year by Esiri<p>A Calendar of Wisdom by Tolstoy<p>God&#x27;s Wisdom for Navigating Life by Tim Keller<p>Those three all fit the daily format.
# 29686739                                                                                                                                                                                                                                                                                                                                   I am wondering what did you read this year and what did you take away from it?
# 29364196                                                                                                                                                                                                                                                                                                             Any reccomendations for an introductory book or textbook?<p>Podcasts or YouTube videos also welcome.
# 29146838  I have been a professional C programmer for around 10+ years, and have been working on systems software (building a database). I have a very cursory knowledge of some other languages like Python. I want to expand my repertoire (while still sticking to backend systems-y stuff like distributed systems&#x2F;storage systems&#x2F;infrastructure level programming). I have been thinking of picking up...
# 25999330                                                                                                                                                                                                                                                                                                                                                                                                             <NA>
# 25824260  I have the impression that statistics is a very special subject in the way learning resources are distributed in terms of complexity and rigor.<p>There are plenty of elementary books where mathematics is also non-existent as such and there is just plenty of hand-waving.<p>On the other hand, there is the upper-division category where there is plenty of math, derivations, proofs and rigor, but i...
# 28830391                                                                                                              I am familiar with top down networking by Kurose and Ross. I liked the book a lot and I am looking for a similar book for advanced practical networking concepts like vpns, nats etc. Like the title asks, what books&#x2F;blogs&#x2F;courses would you recommend for advanced networking concepts?
# 26909996                                                                                                                                                                                                                                                                       I mention 2021 as it seems that Figma is now king on many design fronts, but I understand that some books may pre-date it and be timeless.
# 29538595                                                                                                                                                                                                                                                                                                                                                                                                             <NA>
# 27802522                                                                                                                                                                                                                                                                                                                                                                                                             <NA>
# 28659636                                                                                                                                                                                                                             Whole language is an approach to, or attitude toward
# learning that sees language as a whole entity, and writing, speaking,
# reading, and listening should be integrated when learned.
# 27807639                                                                                                                                                                            One of my favorites:<p>Hard Landing: The Epic Contest for Power and Profits That Plunged the Airlines into Chaos<p>https:&#x2F;&#x2F;www.amazon.com&#x2F;Hard-Landing-Contest-Profits-Airlines&#x2F;dp&#x2F;0812928350&#x2F;ref=nodl_
# 28124164                                                                                                                                                                                                                                                                                                                                                                                                             <NA>
# 28588411                                                                                                                                                                                                                                                                                  Curious to hear about any textbooks or technical books that you have enjoyed reading and&#x2F;or found to be very high-quality.
# 26624661  Dear readers, I&#x27;d like to study the business side of software engineering: how to design a product, how to monetize it, how to study competitors, evaluate partners, make estimation of revenues and similar. In my ignorance I would call such knowledge &quot;business modelling&quot; but I may be wrong.<p>Are you aware of any good reputable up-to-date book&#x2F;resource on such topic?<p>Thank...
# 26087495                                                                                                                                                                                                                                                      What are your (book) recommendations on how to create a tech startup, from the idea to finding your partners to launch, whilst observing social distancing.
# 29573390  I&#x27;m trying to disconnect myself from Amazon as much as I can.  Where this burns me is purchasing (used) technical books.  I&#x27;ve been trying to leverage my local library system more but the majority of the technical, CompSci-esque books are laughable.  I found one book that&#x27;s good and I&#x27;m working through it, but most of the stuff there is &quot;Windows 8.1 for Dummies&quot; a...
# 26317481                                                                                                                                                                                                                                                                                                                                                                                                             <NA>
# 28267422                                                                                                                                                                                                                                                                                                                                                                                                             <NA>
# 27846316  Eleven years after graduating I have rediscovered how enjoyable it is to flip through a high quality intro textbook on a topic about which you are curious.<p>I’ll go first:<p>Calculus and Analytic Geometry (1951) by George Thomas<p>It’s readily available for &lt; $10 and I find it’s style much more engaging than contemporary textbooks on the same topic.<p>And a bonus one - when we had question...
# 25846115                                                                                                                                                                                                                                                                                                                                                                                                             <NA>
# 26774350                                                  I have two kids under the age of 4, and we have SO MANY garbage toddler books. I&#x27;d love recommendations for books that might help stimulate intellectual curiosity, or at least are less painful to read 100+ times. An example of the type of book I&#x27;m looking for is &#x27;Rosie Revere, Engineer&#x27;. Any suggestions would be much appreciated!
# 27839815                                                                                                                                              Looking for &quot;coffee table books&quot; from which you can learn something by reading just a couple of pages, optionally with some imagery.<p>Something in the lines of: Thing Explainer by Randall Munroe (xkcd), The secret lives of color by Kassia St.Clair.
# 26833319                                                                                                                                 We all know the most popular books for software engineers. One could just google it (e.g., Clean Code, DDIA, SICP, TAOCP, K&amp;R books, Steven&#x27;s books, etc.).<p>What are the not-so-popular-but-still-good books in computer science&#x2F;software engineering out there?
# 29457470  I am looking for a comprehensive resource on data visualization. There are many individual resources that have been posted over the years (such as in blog posts). However, as a non-expert I am not sure which advice is good to follow (e.g., many blogs are published by companies trying to sell me a particular product or package).<p>Not sure if the book is the ideal format for this, but it seems ...
# 29182386                                                                                                                                                                                                                                                                             I&#x27;m curious if you have a favorite CS book specifically for the way it was written and how the author communicated their ideas.
# 29726026                                                                                                                                                              Daniel Kahneman’s assertion that we’re not great intuitive statisticians got me thinking how poorly I understood stat despite intro classes in college.<p>What is your favorite book that transformed the way you interpret and produce statistics?
# 25922349                                                                                                                                                                                                                                                                                                                                                                                                             <NA>
# 26511180                                                                                                                                                                                                                                                                                          I&#x27;m trying to get into AI or machine learning, what do you recommend for me? Mostly practical not academic please.
# 27641976                                                                                                                                                                                                                                                                                                                                                                                                             <NA>
# 29661400  This insightful thread [1] today suggests importance for developer to &quot;know its hardware&quot;.<p>Any materials (books, videos, courses, tutorials, example codebases) you&#x27;d suggest to learn this?<p>I like the &quot;Write Great Code&quot; series [2], esp. &quot;Understanding the Machine&quot; and &quot;Thinking Low-Level, Writing High-Level&quot;. Though I think they miss depth.<p>[1]...
# 29688332                                                                                                                                                                                                                                    Mine are Statistical Inference in Computer Age, and Transactional Information Systems. Curious what other books teach us powerful concepts and tools that carry us a long way
#
#           dead               by  score        time                 timestamp  \
# id
# 29710173  <NA>   wizardofmysore      5  1640663827 2021-12-28 03:57:07+00:00
# 28659626  <NA>       cylde_frog      3  1632650305 2021-09-26 09:58:25+00:00
# 25987664  <NA>     letientai299    302  1612178191 2021-02-01 11:16:31+00:00
# 29668228  <NA>  AccountAccount1    515  1640304895 2021-12-24 00:14:55+00:00
# 28391738  <NA>        eatonphil     62  1630589316 2021-09-02 13:28:36+00:00
# 28308141  <NA>    justinzollars     11  1629931501 2021-08-25 22:45:01+00:00
# 29602228  <NA>            arikr    107  1639808795 2021-12-18 06:26:35+00:00
# 29634694  <NA>           ent101     12  1640069172 2021-12-21 06:46:12+00:00
# 28456318  True  gilbertmpanga12      1  1631105874 2021-09-08 12:57:54+00:00
# 28181074  <NA>           ingvul     10  1628952503 2021-08-14 14:48:23+00:00
# 28162971  <NA>           lgregg      2  1628810355 2021-08-12 23:19:15+00:00
# 29686739  <NA>      mdotmertens      6  1640464575 2021-12-25 20:36:15+00:00
# 29364196  <NA>         f0e4c2f7      5  1638051870 2021-11-27 22:24:30+00:00
# 29146838  True           314156      1  1636356874 2021-11-08 07:34:34+00:00
# 25999330  <NA>    notoriousarun      2  1612262036 2021-02-02 10:33:56+00:00
# 25824260  True      dondraper36      1  1610991542 2021-01-18 17:39:02+00:00
# 28830391  <NA>    imheretolearn     15  1633971441 2021-10-11 16:57:21+00:00
# 26909996  <NA>            nicdc      7  1619140268 2021-04-23 01:11:08+00:00
# 29538595  <NA>         schappim     10  1639394357 2021-12-13 11:19:17+00:00
# 27802522  <NA>        themantri      2  1626022701 2021-07-11 16:58:21+00:00
# 28659636  <NA>       cylde_frog     63  1632650423 2021-09-26 10:00:23+00:00
# 27807639  <NA>     danielrhodes      2  1626071079 2021-07-12 06:24:39+00:00
# 28124164  <NA>             yasp     10  1628557330 2021-08-10 01:02:10+00:00
# 28588411  <NA>       jonpalmisc      3  1632089382 2021-09-19 22:09:42+00:00
# 26624661  <NA>        michele_f     16  1617036734 2021-03-29 16:52:14+00:00
# 26087495  <NA>            elo02      1  1612952683 2021-02-10 10:24:43+00:00
# 29573390  <NA>   slipperlobster     26  1639614793 2021-12-16 00:33:13+00:00
# 26317481  <NA>          kiraken      1  1614704677 2021-03-02 17:04:37+00:00
# 28267422  <NA>      whitepoplar      8  1629652704 2021-08-22 17:18:24+00:00
# 27846316  <NA>       mrtonypino      5  1626365239 2021-07-15 16:07:19+00:00
# 25846115  <NA>   simonebrunozzi     16  1611149096 2021-01-20 13:24:56+00:00
# 26774350  <NA>            mojoe     18  1618182063 2021-04-11 23:01:03+00:00
# 27839815  <NA>            tucif      2  1626305917 2021-07-14 23:38:37+00:00
# 26833319  <NA>        sdevonoes     54  1618578028 2021-04-16 13:00:28+00:00
# 29457470  <NA>            zwaps    105  1638779027 2021-12-06 08:23:47+00:00
# 29182386  <NA>            asoli     75  1636586884 2021-11-10 23:28:04+00:00
# 29726026  <NA>         djklanac     56  1640793890 2021-12-29 16:04:50+00:00
# 25922349  <NA>   react_burger38      1  1611704174 2021-01-26 23:36:14+00:00
# 26511180  <NA>      Moody_10001      2  1616143172 2021-03-19 08:39:32+00:00
# 27641976  <NA>    notoriousarun      4  1624716428 2021-06-26 14:07:08+00:00
# 29661400  <NA>          rmbyrro      5  1640264333 2021-12-23 12:58:53+00:00
# 29688332  <NA>         hintymad     95  1640477353 2021-12-26 00:09:13+00:00
#
#            type  parent  ...  parent36  parent37  parent38  parent39 parent40  \
# id                       ...
# 29710173  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 28659626  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 25987664  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 29668228  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 28391738  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 28308141  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 29602228  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 29634694  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 28456318  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 28181074  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 28162971  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 29686739  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 29364196  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 29146838  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 25999330  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 25824260  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 28830391  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 26909996  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 29538595  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 27802522  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 28659636  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 27807639  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 28124164  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 28588411  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 26624661  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 26087495  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 29573390  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 26317481  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 28267422  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 27846316  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 25846115  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 26774350  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 27839815  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 26833319  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 29457470  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 29182386  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 29726026  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 25922349  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 26511180  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 27641976  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 29661400  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
# 29688332  story    <NA>  ...      <NA>      <NA>      <NA>      <NA>     <NA>
#
#          parent41 parent42 parent43  root depth
# id
# 29710173     <NA>     <NA>     <NA>  <NA>     0
# 28659626     <NA>     <NA>     <NA>  <NA>     0
# 25987664     <NA>     <NA>     <NA>  <NA>     0
# 29668228     <NA>     <NA>     <NA>  <NA>     0
# 28391738     <NA>     <NA>     <NA>  <NA>     0
# 28308141     <NA>     <NA>     <NA>  <NA>     0
# 29602228     <NA>     <NA>     <NA>  <NA>     0
# 29634694     <NA>     <NA>     <NA>  <NA>     0
# 28456318     <NA>     <NA>     <NA>  <NA>     0
# 28181074     <NA>     <NA>     <NA>  <NA>     0
# 28162971     <NA>     <NA>     <NA>  <NA>     0
# 29686739     <NA>     <NA>     <NA>  <NA>     0
# 29364196     <NA>     <NA>     <NA>  <NA>     0
# 29146838     <NA>     <NA>     <NA>  <NA>     0
# 25999330     <NA>     <NA>     <NA>  <NA>     0
# 25824260     <NA>     <NA>     <NA>  <NA>     0
# 28830391     <NA>     <NA>     <NA>  <NA>     0
# 26909996     <NA>     <NA>     <NA>  <NA>     0
# 29538595     <NA>     <NA>     <NA>  <NA>     0
# 27802522     <NA>     <NA>     <NA>  <NA>     0
# 28659636     <NA>     <NA>     <NA>  <NA>     0
# 27807639     <NA>     <NA>     <NA>  <NA>     0
# 28124164     <NA>     <NA>     <NA>  <NA>     0
# 28588411     <NA>     <NA>     <NA>  <NA>     0
# 26624661     <NA>     <NA>     <NA>  <NA>     0
# 26087495     <NA>     <NA>     <NA>  <NA>     0
# 29573390     <NA>     <NA>     <NA>  <NA>     0
# 26317481     <NA>     <NA>     <NA>  <NA>     0
# 28267422     <NA>     <NA>     <NA>  <NA>     0
# 27846316     <NA>     <NA>     <NA>  <NA>     0
# 25846115     <NA>     <NA>     <NA>  <NA>     0
# 26774350     <NA>     <NA>     <NA>  <NA>     0
# 27839815     <NA>     <NA>     <NA>  <NA>     0
# 26833319     <NA>     <NA>     <NA>  <NA>     0
# 29457470     <NA>     <NA>     <NA>  <NA>     0
# 29182386     <NA>     <NA>     <NA>  <NA>     0
# 29726026     <NA>     <NA>     <NA>  <NA>     0
# 25922349     <NA>     <NA>     <NA>  <NA>     0
# 26511180     <NA>     <NA>     <NA>  <NA>     0
# 27641976     <NA>     <NA>     <NA>  <NA>     0
# 29661400     <NA>     <NA>     <NA>  <NA>     0
# 29688332     <NA>     <NA>     <NA>  <NA>     0
#
# [42 rows x 59 columns]

# %% [markdown]
# We can now find all their threads

# %%
book_recommendation_threads = df[df.root.isin(book_recommendations.index)]

# %% [markdown]
# Interconnections by radia perlman interconnections
#
# How to Build a Car by Adrian Newey
#
# Liftoff by Eric Berger
#
# The Pragmatic Programmer: From Journeyman to Master by Andy Hunt

# %% [markdown]
# Let's clean the text to make it easier to read

# %%
import re

def clean(text):
    text = html.unescape(text)
    text = text.replace('<i>', '*')
    text = text.replace('</i>', '*')
    text = text.replace('<p>', '\n\n')
    text = re.sub('<a href="(.*?)".*?>.*?</a>', r'\1', text)
    return text

# %% [markdown]
# Almost all the top level children contain a book recommendation.

# %%
for _id, row in book_recommendation_threads.query('depth==1').dropna(subset='text').sample(10).iterrows():
    print(_id, row.depth, df.loc[row.root].title)
    print(clean(row.text))
    print()
# Out:
# 29288060 1 Ask HN: What are some of the best well-written books on computer science?
# Designing Data-Intensive Applications: The Big Ideas Behind Reliable, Scalable, and Maintainable Systems
# by Martin Kleppmann
# https://www.amazon.com/Designing-Data-Intensive-Applications-Reliable-Maintainable/dp/1449373321
#
# You can learn a lot of algorithms. It's useless unless you start to create architecture and use them in practice.
#
# 29603708 1 Ask HN: What are the best books for professional effectiveness?
# yep, the happiness project: https://gretchenrubin.com/books/the-happiness-project/about-the-book/
#
# Hear me out :)
#
# It teaches you to do a lot of little things that over time make a huge impact on your well being and the people around you. I loved this book and found a huge impact on my life year after year as little habits it teaches started to add up.
#
# In the workforce it also helped me. I am already very empathetic, but it helped me do a lot of little things for my team and the people I manage to make their lives better.
#
# Great book.
#
# 26837383 1 Ask HN: Best book for software engineers (besides the well-known ones)?
# Books, concepts, and mindsets that help build the right thing. Problem solving, design, design thinking, consulting resources.
#
# "The Complete Problem Solver", "Change by Design", "The Design of Everyday Things", "Jobs to Be Done", concepts like non-consumption. Questions that confirm that feature requests are valid and avoid solving Y problem when the actual problem is X. Thought processes to prioritize work and focus on what matters.
#
# Example: https://news.ycombinator.com/item?id=26814150
#
# Then books, concepts, and mindsets that help software engineers reap the reward of the software they write. Marketing, sales, prospecting, pricing, communication.
#
# I believe there is a huge quantity of beautiful, idiomatic, code that solves no real problem, and a huge number of software engineers who have trouble monetizing their skill, or get stuck in unfulfilling roles because they have not found a way to shape an interesting one for themselves.
#
# A few examples of threads searching for answers one usually answers through piecing together many resources, books, and life experiences:
#
# https://news.ycombinator.com/item?id=26805216
#
# https://news.ycombinator.com/item?id=26650563
#
# https://news.ycombinator.com/item?id=26550896
#
# https://news.ycombinator.com/item?id=26465891
#
# https://news.ycombinator.com/item?id=26446169
#
# https://news.ycombinator.com/item?id=26366426
#
# 29691950 1 Ask HN: What is your favorite book that you've read this year?
# I enjoyed Freedom by Sebastian Junger, I actually read it twice. I like the directness of his writing plus I've always admired the general sense of humanity he portrays. I reread The Road by Cormac McCarthy, for me his writing style is simply a different dimension to other writers, I tend to read this every year or so.
#
# 26774992 1 Ask HN: What are your favorite toddler books?
# That's the secret to writing children's books.  You have to write something an adult can read 100 times without going insane.
#
# One I really liked was *The Bravest Ever Bear*.  I forget who it's by, but it is pretty good by the "adult reading 100 times" test.  It may be for kids a bit older than 4, but not a lot.
#
# 29182730 1 Ask HN: What are some of the best well-written books on computer science?
# The C Programming Language, 2nd edition.
#
# Introduction To Operating System Abstractions Using Plan9 From Bell Labs.
#
# https://doc.cat-v.org/plan_9/9.intro.pdf
#
# Today you can just use 9front.
#
# 28662568 1 Ask HN: What is the best programming book you've read?
# The Little Schemer is my favorite by far! so easy to understand and follow. Definitely a must read if you want to get into functional programming
#
# 29671689 1 Ask HN: What's the best book you read in 2021?
# Ordinary Men. A great book about a bunch of ordinary men (50 year old police reservists, from Hamburg, of different socioeconomic classes and political leanings) and the atrocities they committed during WW2 in Poland ( mostly against Jews), why, and how they coped with it. There are some fascinating pieces of information there ( post-war interviews with the men form a big part of the narrative establishing what happened), and it really reinforced some of my already established opinions on "bad people", the Nazis, etc. There was nothing unique about them and such terrible things can happen again, which is why it's so important to teach and remember history - if you don't know how the Nazis convinced millions to do unspeakable things, you can more easily fall in the same trap.
#
# 29669818 1 Ask HN: What's the best book you read in 2021?
# The Quantum Thief by Hannu Rajaniemi.
#
# It's chock full of ideas that any technologist would find fascinating. A post-singularity society in which those who "got there first" ascended to technological godhood, and the rest mostly fight for comparative scraps.  Those scraps are phenomenally interesting though, and the many ways the book assumes and implies generations of growth in technology make for some truly out-there settings and cultures. If you liked the part of Anathem where you had no idea what was going on at first, but slowly learned the ways of the world as you read on... you'd love this book.
#
# 29672941 1 Ask HN: What's the best book you read in 2021?
# Crucial Conversations. It was actually recommended to me in an HN thread. Literally life changing

# %% [markdown]
# The second level comments contain some books, but it's much less likely

# %%
for _id, row in book_recommendation_threads.query('depth==2').dropna(subset='text').sample(10).iterrows():
    print(_id, row.depth, df.loc[row.root].title)
    print(clean(row.text))
    print()
# Out:
# 29675450 2 Ask HN: What's the best book you read in 2021?
# The most important part of this book is the thoughtful explanation and deep dive into psychedelics. Sure you might come away with "I should try this", but it explains how and why these drugs (*medicines) should be used, especially the potential downsides and adverse effects.
#
# 29671338 2 Ask HN: What's the best book you read in 2021?
# I don't mean this in a cynical way, but how come you didn't expect a literary classic to be well-written?
#
# 29670440 2 Ask HN: What's the best book you read in 2021?
# (I) think of the baroque cycle as fictionalized history rather than historical fiction
#
# 29607659 2 Ask HN: What are the best books for professional effectiveness?
# I just picked up How to take Smart Notes. In undergrad a lifetime ago, I remember feeling that my note taking skills were woefully inadequate. My notes became more scattered, less comprehensive, and on the whole less reliable to use as semesters went on.
#
# I think there's something important here to learn, so thanks.
#
# edit: This reading is relevant because I'm going back to school, but I'm part way through and can see this will also be useful for all the books I read about stuff I find interesting. The idea of a slip box to capture, refine, and connect information sounds fun.
#
# 29670277 2 Ask HN: What's the best book you read in 2021?
# Creativity, Inc is also a great read if you're still left wanting some more Pixar stories!
#
# 29674069 2 Ask HN: What's the best book you read in 2021?
# Interesting. The idea of "getting into flow" is one of the most powerful and imperative to understand. I'll add it to my list.
#
# 29670466 2 Ask HN: What's the best book you read in 2021?
# Two thumbs up for every book by Nassim Taleb!
#
# 29669954 2 Ask HN: What's the best book you read in 2021?
# I almost got past this recommendation without having to read another sci-fi book but your Anathem pitch got me.
#
# I’ve been stuck in sci-fi for 3 years straight and thought I was finally going to read something else before 2022.
#
# Bah humbug!
#
# 29672058 2 Ask HN: What's the best book you read in 2021?
# Seen an optician lately? You should see a doctor after that. Take care of yourself.
#
# 28663500 2 Ask HN: What is the best programming book you've read?
# I agree.
#
# About 20 years ago C# was the second language that I'd learnt after C/C++ and remember just picking the C# language spec and learning from it rather than any of the books at that time since all the books were so wordy/verbose that it just didn't make sense. Especially having learnt C from K&R.
#
# I haven't looked lately at other language specs, and don't remember others, but at that time the C# language spec was very well written.

# %% [markdown]
# This gives us over 500 posts, most of which contain a book.

# %%
len(book_recommendation_threads.query('depth==1'))
# Out:
# 537

# %%
(
    book_recommendation_threads
    .query('depth==1 & dead.isna() & text.notna()')
    .merge(df[['title', 'text']], how='left', left_on='root', right_index=True, suffixes=('', '_parent'))
    [['text', 'by', 'timestamp', 'root', 'title_parent', 'text_parent']]
).to_csv('../data/02_intermediate/hn_ask_book_recommendations.csv')

# %% [markdown]
# We could get some titles from here by looking for italics.

# %%
book_recommendation_threads.text.dropna().str.extractall('<i>(.*?)</i>').head(30)
# Out:
#                                                                                      0
# id       match
# 29673970 0                                                              The Peripheral
# 29669067 0                                                                      Reaper
# 29670564 0         The Unwomanly Face of War: An Oral History of Women in World War II
#          1                                                                    Beanpole
#          2                                                           Klara and the Sun
# 29671265 0                                                         Three Men in a Boat
#          1                                                             Tristram Shandy
# 29672389 0                                                                   essential
# 29692384 0          Designing Distributed Control Systems: A Pattern Language Approach
# 29616178 0                                                     Difficult Conversations
# 29607825 0                                           The Unwritten Laws of Engineering
# 26834528 0                                      The Psychology of Computer Programming
#          1                                             A Philosophy of Software Design
# 26833412 0                              Software Engineering for Internet Applications
#          1                                                                  About Face
#          2                                          The Inmates Are Running the Asylum
# 25847496 0                                             without expecting reciprocation
# 29676409 0                                                                 Loyal Books
# 26774992 0                                                       The Bravest Ever Bear
# 29671523 0                                                                       a ton
# 29669285 0      Colossus: The secrets of Bletchley Park&#x27;s code-breaking computers
# 29669759 0                                               One Hundred Years of Solitude
# 29670222 0                                                                      really
# 29185469 0                                                          The Little Schemer
# 29669793 0                                                              Attack Surface
#          1                                      Engineering General Intelligence Vol 2
#          2                                                                      Daemon
#          3                                                                     Freedom
#          4                                                               Billy Summers
#          5                                                                   Elsewhere

# %% [markdown]
# And others by looking for "Book by Author"; which works somewhat.

# %%
book_recommendation_threads.text.dropna().apply(clean).str.extractall(r'[*"“]?([^.*"“\n]+?)[*"”]?[, ]*\bby\b((?:[^[A-Z]\w+)+)').head(30)
# Out:
#                                                                                                                                                                       0  \
# id       match
# 29669495 0                                                                                                                                  The Coming of Neo-Feudalism
# 29669067 0                                                                                                                                                       Reaper
# 29670033 0                                                                                                                                        A Gentleman in Moscow
# 29670439 0                                                                                                                                                In Cold Blood
# 25989272 0                                                                                                                                                          CSP
#          1                                                                                       Making reliable distributed systems in the presence of software errors
#          2                                                                                                                          Conflict-free Replicated Data Types
# 25867397 0                                                                                                                                               very relatable
# 25988717 0                                                              The best and most accessible book on theory is probably Reliable and Secure Distributed systems
# 29672082 0                                                                                                                         Thanks for pointing out the new book
# 29673419 0                                                                                                             by Benjamín Labatut, translated from the Spanish
# 29669135 0                                                                                                                     Endurance: Shackletons Incredible Voyage
# 29669325 0                                                                  I think best overall was one of the ones I read way early in the year, Beyond Good and Evil
#          1                                                                                                                              I had been saving The Pale King
# 29673081 0                                                                                                                                                 The Hospital
#          1                                                                                                                                      This book really opened
# 26000803 0                                                                                                                                                  Release It!
# 29471645 0                                                                                                                                   Better Data Visualizations
# 29670452 0                                                                                                         The short answer is that the first book was inspired
#          1                                                                                                                                     The others were inspired
# 29671549 0                                                                                                                                         Miracle In the Andes
#          1                                                                                                                                                       Adrift
# 29634728 0                                                                                           The Origin of Consciousness in the Breakdown of the Bicameral Mind
# 29669974 0                                                                                                                                                Radical Focus
# 29672015 0                                                                                  I imagined, in an extremely vivid and negative way, how I would be judged -
# 29672931 0                                                                                                                              Why greatness cannot be planned
#          1      It's a bit depressing that academia works the way it does, but in a twisted way it gives me hope that I could make a significant contribution somewhere
# 29616178 0                                                                                                                                                    , written
# 29672307 0                                                                                                                                           How to Build a Car
#          1                                                                                                                         And while his career has been marked
#
#                                                                                                                                                              1
# id       match
# 29669495 0                                                                                                                                         Joel Kotkin
# 29669067 0                                                                                                                                          Will Wight
# 29670033 0                                                                                                                                         Amor Towles
# 29670439 0                                                                                                                                       Truman Capote
# 25989272 0                                                                                                                                          Tony Hoare
#          1                                                                                                                                       Joe Armstrong
#          2                                                                                                                                        Marc Shapiro
# 25867397 0                                                                                                                                    modern standards
# 25988717 0                                                                                                                                              Cachin
# 29672082 0                                                                                                                                     Neal Stephenson
# 29673419 0                                                                                                                                  Adrian Nathan West
# 29669135 0                                                                                                                Lansing is an amazing survival story
# 29669325 0                                                                                                                                           Nietzsche
#          1                                                                                                                         David Foster Wallace for an
# 29673081 0                                                                                                                                     Brian Alexander
#          1       eyes to those communities that have never recovered from the Great Recession and explains so much of what we have seen politically since 2016
# 26000803 0                                                                     Michael Nygard is a good book on resilience engineering for distributed systems
# 29471645 0                                                                                                                      Jonathan Schwabish is the best
# 29670452 0                                                                an idea he had while talking to a professor about the rise and fall of civilizations
#          1                                                                                                            pressure by publishers to repeat success
# 29671549 0                                                                                                                                             Nando X
#          1                                                                                                                                            Callahan
# 29634728 0                                                                                                                                       Julian Jaynes
# 29669974 0                                                                                                                                    Christina Woldke
# 29672015 0                                                                                                                                          my friends
# 29672931 0                                                                                                                                     Kenneth Stanley
#          1                                                                                                  just tinkering or following what feels interesting
# 29616178 0                                                                   a team at Harvard that spent years on practicing and refining conflict-resolution
# 29672307 0                                                                                                                                        Adrian Newey
#          1                                                                                                                               unbelievable triumphs
